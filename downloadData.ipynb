# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
TICKERS = ["MSFT", "KO", "META", "GLD", "MS", "TSM", "AAPL"]
START = "2020-01-01"
END = "2025-01-01"

# %%
data = yf.download(TICKERS, start=START, end=END)
data = data.drop(columns=["Volume"])
# Out:
# C:\Users\olive\AppData\Local\Temp\ipykernel_17148\789625665.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(TICKERS, start=START, end=END)
# [*********************100%***********************]  7 of 7 completed

# %%
data.describe()
# Out:
# Price         Close                                                      \
# Ticker         AAPL          GLD           KO         META           MS
# count   1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean     151.806049   180.883593    52.634073   299.768842    75.256907
# std       41.970401    23.951219     7.471059   124.631881    20.709280
# min       54.316940   138.039993    31.740849    88.365257    23.308393
# 25%      126.636370   166.472500    47.425504   208.507114    67.649153
# 50%      150.392883   174.989998    54.505835   279.193832    78.521164
# 75%      176.399658   185.079998    57.526873   344.786980    87.483931
# max      258.103729   257.500000    70.395622   630.696838   132.112518
#
# Price                                    High                            ...  \
# Ticker         MSFT          TSM         AAPL          GLD           KO  ...
# count   1258.000000  1258.000000  1258.000000  1258.000000  1258.000000  ...
# mean     287.533652   101.769860   153.332134   181.681455    53.026122  ...
# std       81.572007    36.101679    42.111163    24.010632     7.435834  ...
# min      129.171265    39.919281    55.316759   140.500000    32.864791  ...
# 25%      227.971066    80.278446   127.757518   167.052502    47.694310  ...
# 50%      275.338699    96.326839   152.138966   175.514999    54.991562  ...
# 75%      332.321243   113.719294   177.954457   185.975002    57.902936  ...
# max      463.240967   205.802704   259.179926   257.709991    70.897006  ...
#
# Price           Low                                   Open               \
# Ticker           MS         MSFT          TSM         AAPL          GLD
# count   1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean      74.402622   284.503738   100.506973   151.651296   180.891169
# std       20.618453    81.222793    35.564247    41.914048    23.957801
# min       22.797131   126.405063    38.836941    55.215083   137.559998
# 25%       66.816073   224.781694    79.644166   126.080083   166.525002
# 50%       77.672906   272.160085    95.530467   150.212640   175.060005
# 75%       86.635107   329.795885   112.518189   176.205315   184.979996
# max      131.104474   460.169610   203.013810   257.276679   256.760010
#
# Price
# Ticker           KO         META           MS         MSFT          TSM
# count   1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean      52.645757   299.611064    75.246030   287.460539   101.856781
# std        7.442007   124.786667    20.734896    81.640095    36.209477
# min       32.754931    89.528087    24.431488   130.687870    39.463029
# 25%       47.386366   207.605183    67.497143   228.154853    80.364929
# 50%       54.541622   277.464517    78.698326   275.853910    96.491952
# 75%       57.592934   344.543503    87.504093   332.213203   113.951202
# max       70.675246   629.520541   132.552923   462.686155   204.373517
#
# [8 rows x 28 columns]

# %%
log_returns = np.log(data["Close"] / data["Close"].shift(1))

# %%
# Basic Graph to for visual check
fig, ax = plt.subplots()
ax.plot(log_returns.cumsum())
fig.legend(log_returns.columns)

# %%
data.to_csv("data.csv")
